# %%
PATH_TO_AS7263_DATA = '../HarvardMuseumData/IlluminationSources/'
SPECTRASUITE_DATA_FILE = '../SpectraSuiteData/HalogenReferenceSpectrumGavin.txt'
SILICON_CALIBRATION_DATA = '../ML_Test_Data/LightSourceDirect_ForSiliconCallibration.csv'
CALIBRATION_FROM_CD = '../../lightcalibrationfromCD.txt'
BAND = np.array([610,680,730,760,810,860])
SILICON_SPECTRAL_RESPONSE = np.array([0.72,0.8,0.85,0.9,0.93,0.97])
FDS1010_SPECTRAL_RESPONSE = np.array([0.33,0.4,0.46,0.51,0.56,0.62])
SAMPLE_CALIBRATION_READING = [588.87,690.17,1337.43,1445.13, 2358.97,2326.74]

# %%
print SILICON_CALIBRATION_DATA
# Out:
# ../ML_Test_Data/LightSourceDirect_ForSiliconCallibration.csv

# %%
import csv
import numpy as np
import pandas as pd
import os 
import sklearn.preprocessing as prep

#%matplotlib inline
import matplotlib.pyplot as plt

# %%
def CSVtoNumpy(csvFile):
    df=pd.read_csv(csvFile, sep=',',header=None)
    return df.values

# %%
colors = ['red','blue','green','orange','lime','fuchsia','black','yellow','turquoise']

def PlotIlluminationSources(path): 
    for i,csvFile in enumerate(os.listdir(path)): 
        #skip the DS_Store directory (auto-generated by Dropbox(?))
        if(csvFile == '.DS_Store'): 
            continue 
        else:
            key = csvFile.split('.')[0]
            if key == 'MITPointBulbatSensorClose':
                continue
            elif key == 'MITPointBulbatSensorFar2':
                raw_data = CSVtoNumpy(path + csvFile)
                raw_data = np.delete(raw_data, -1, 1)
                print 'key: ' + str(key) + ' color:' + colors[i]
                plt.plot(BAND,np.transpose(raw_data),color=colors[i],linewidth='3')

# %%
PlotIlluminationSources(PATH_TO_AS7263_DATA)
# Out:
# key: MITPointBulbatSensorFar2 color:black

# %%
plotSpectraSuiteData()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-4749f125ccae> in <module>()
# ----> 1 plotSpectraSuiteData()
#
# NameError: name 'plotSpectraSuiteData' is not defined

# %%
    data1 = [[525.25, 516.48, 1226.07, 1293.91, 1550.77, 1447.7],
    [496.82, 421.64, 1184.92, 1227.88, 1505.99, 1025.75],
    [484.63, 366.79, 1137.72, 1175.7, 1449.75, 955.43],
    [490.05, 363.37, 1153.45, 1195.93, 1454.96, 1028.18],
    [454.85, 311.95, 1065.1, 1101.15, 1383.09, 851.16],
    [468.39, 371.37, 1082.04, 1129.91, 1378.93, 1121.54],
    [431.84, 311.95, 986.43, 1035.13, 1279.99, 1034.24],
    [422.36, 297.09, 962.22, 1008.5, 1268.53, 892.38],
    [411.53, 254.81, 938.01, 988.27, 1209.17, 911.78],
    [410.18, 210.25, 946.49, 980.81, 1201.88, 717.79],
    [416.95, 405.64, 922.28, 1002.11, 1236.24, 1282.8],
    [423.72, 347.37, 979.16, 1033.0, 1251.87, 1092.44]]
    
    data2=[[67.69, 394.22, 580.96, 658.14, 296.82, 83.66],
    [69.04, 391.93, 574.91, 641.1, 293.7, 55.77],
    [62.27, 356.51, 525.29, 644.29, 268.7, 43.65],
[821.71, 388.51, 1059.05, 1317.34, 3214.03, 3162.14],
[820.36, 386.22, 1057.84, 1317.34, 3211.95, 3152.44],
[819.01, 385.08, 1051.79, 1313.08, 3208.82, 3134.25],
[816.3, 382.79, 1048.15, 1309.88, 3204.65, 3119.7],
[814.94, 381.65, 1044.52, 1306.69, 3201.53, 3106.36],
[813.59, 379.36, 1040.89, 1303.49, 3199.45, 3091.81],
[812.24, 378.22, 1037.26, 1301.36, 3196.32, 3080.9],
[810.88, 377.08, 1034.84, 1300.3, 3193.2, 3069.99],
[810.88, 375.94, 1032.42, 1297.1, 3192.16, 3059.08],
[809.53, 373.65, 1028.79, 1293.91, 3187.99, 3045.74],
[808.18, 372.51, 1026.37, 1292.84, 3186.95, 3036.04],
[806.82, 371.37, 1022.74, 1289.65, 3183.83, 3023.91],
[805.47, 370.22, 1021.53, 1288.58, 3181.74, 3016.64],
[805.47, 370.22, 1020.32, 1287.52, 3180.7, 3009.37],
[805.47, 369.08, 1019.11, 1287.52, 3179.66, 3003.3],
[804.11, 369.08, 1017.9, 1286.45, 3179.66, 2996.03],
[804.11, 367.94, 1016.69, 1285.39, 3176.53, 2989.97],
[802.76, 367.94, 1015.47, 1284.32, 3176.53, 2983.9],
[794.64, 359.94, 982.8, 1251.31, 3166.12, 2909.94],
[793.28, 354.23, 979.16, 1248.11, 3158.83, 2899.03],
[794.64, 353.08, 986.43, 1255.57, 3157.79, 2909.94],
[798.7, 362.22, 1002.16, 1272.61, 3166.12, 2939.04],
[797.35, 362.22, 998.53, 1268.35, 3166.12, 2929.34],
[795.99, 359.94, 997.32, 1267.28, 3164.04, 2923.28],]

# %%
plt.plot(np.transpose(np.array(data3)))
plt.show()

# %%
PROFTHIRDBANDVAL = np.float64(0.972550332258)
def calcvalue(spectrum):
    val =  spectrum[2] / PROFTHIRDBANDVAL
    return spectrum / val

# %%
#plotAS7263Data(data4)
#plotAS7263Data(dataGavin4)
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex='col', sharey='row',figsize=(10,8))
#plt.xlabel('Wavelength (nm)')
(a,b) = plotSpectraSuiteData(SPECTRASUITE_DATA_FILE)
(c,d) = plotAS7263NormalizedData2(dataGavin2)
ax1.plot(c,d)
ax1.plot(a,b,label='Ocean Optics USB4000')
ax1.legend()
(e,f) = plotAS7263NormalizedData2(dataGavin3)
ax2.plot(a,b,label='Ocean Optics USB4000')
ax2.plot(e,f)
ax2.legend()
(g,h) = plotAS7263NormalizedData2(data1)
ax3.plot(a,b,label='Ocean Optics USB4000')
ax3.plot(g,h)
ax3.legend()
(i,j) = plotAS7263NormalizedData2(data4)
ax4.plot(a,b,label='Ocean Optics USB4000')
ax4.plot(i,j)
ax4.legend()
fig.suptitle('AS7263 vs. OceanOptics USB4000 Normalized Spectral Response\nTo Halogen Bulb Under Miniscule Angle/Distance Displacements')
ax3.set_xlabel('Wavelength (nm)')
ax1.set_ylabel('Normalized Intensity')
ax3.set_ylabel('Normalized Intensity')
ax4.set_xlabel('Wavelength (nm)')
#plt.subplot(223)
#plotSpectraSuiteData(SPECTRASUITE_DATA_FILE)
#plotAS7263NormalizedData2(data1)
#plt.subplot(224)
#plotSpectraSuiteData(SPECTRASUITE_DATA_FILE)
#plotAS7263NormalizedData2(data4)
#plotAS7263NormalizedData(data2)
#plt.savefig('../results/lightComparison5')
#plt.plot(BAND,np.transpose(dataGavin5))
#f.suptitle('AS7263 vs. OceanOptics USB4000 Normalized Spectral Response \n To Halogen Bulb Under Miniscule Angle/Distance Displacements')
#plt.xlabel('Wavelength (nm)')
fig.subplots_adjust(wspace=0.025, hspace=0.025)
#plt.show()
plt.savefig('../results/AS7263vsSpectraSuiteHalogen')
# Out:
# (3648,)
# (3648,)
# 62079.98
# 79459.61
# 1550.77
# 2471.03

# %%
silicon_test = CSVtoNumpy(SILICON_CALIBRATION_DATA)

# %%
def plotSpectraSuiteData(filepath):
    spectrasuite = open(filepath,'r')
    bands = []
    values = []
    vals = []
    data = spectrasuite.read().split('\n')
    #print data
 
    #plt.plot(data[0].split('\t')[0],data[0].split('\t')[1])
    
    for row in data: 
        vals.append([a for a in row.split('\t')])
  
    for val in vals:
        if(val[0] and val[1]): 
            bands.append(float(val[0]))
            values.append(float(val[1]))   
    print np.shape(bands)
    print np.shape(values)
    maxval = np.max(values)
    normalized_values = [a / maxval for a in values]
    #print bands[1910]
    #print normalized_values[1910]
    added_bands = [a for a in bands]
    return ((added_bands,np.transpose(normalized_values)))
    #plt.plot(added_bands,np.transpose(normalized_values),label='Ocean Optics USB4000')

# %%
#NORMALIZED WITH RESPECT TO ONE OF THE HIGH RESOLUTION DETECTOR BANDS
def plotAS7263NormalizedData(data):
    maxval = np.max(data)
    print maxval
    normalized_data = [calcvalue(spectrum) for spectrum in data]
    plt.plot(BAND,np.transpose(normalized_data))

# %%
#NORMALIZED WITH RESPECT TO 1
def plotAS7263NormalizedData2(data):
    maxval = np.max(data)
    print maxval
    normalized_data = [spectrum / maxval for spectrum in data]
    return((BAND,np.transpose(normalized_data)))
   # plt.plot(BAND,np.transpose(normalized_data))

# %%
#plt.plot(BAND,np.transpose(silicon_test),c='red')
#divided = SAMPLE_CALIBRATION_READING / SILICON_SPECTRAL_RESPONSE
#plt.plot(BAND,np.transpose(divided),c='green')
 
plotAS7263NormalizedData2(silicon_test)
plotSpectraSuiteData(SPECTRASUITE_DATA_FILE)
#plotSpectraSuiteData(SILICON_CALIBRATION_DATA)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-259695aee706> in <module>()
#       3 #plt.plot(BAND,np.transpose(divided),c='green')
#       4
# ----> 5 plotAS7263NormalizedData2(silicon_test)
#       6 plotSpectraSuiteData(SPECTRASUITE_DATA_FILE)
#       7 #plotSpectraSuiteData(SILICON_CALIBRATION_DATA)
#
# NameError: name 'plotAS7263NormalizedData2' is not defined

# %%
cd_calibration_data = [[300.00,1.1803E-3],
[310.00,4.8203E-4],
[320.00,6.3487E-4],
[330.00,9.1077E-4],
[340.00,4.6696E-4],
[350.00,2.5226E-3],
[360.00,4.0942E-3],
[370.00,5.6465E-3],
[380.00,7.5406E-3],
[390.00,9.788E-3],
[400.00,1.2922E-2],
[420.00,2.1393E-2],
[440.00,3.3935E-2],
[460.00,5.1654E-2],
[480.00,7.6627E-2],
[500.00,1.1127E-1],
[525.00,1.6738E-1],
[550.00,2.3766E-1],
[575.00,3.2994E-1],
[600.00,4.2729E-1],
[650.00,6.6036E-1],
[700.00,9.2494E-1],
[750.00,1.2791E0],
[800.00,1.7312E0],
[850.00,2.2803E0],
[900.00,2.929E0],
[950.00,3.5216E0],
[1000.00,4.654E0],
[1050.00,5.6673E0]]

# %%
bands = []
vals = []
for i in cd_calibration_data: 
    bands.append(i[0])
    vals.append(i[1])
    
maxval = np.max(vals)
plt.plot(bands,np.array(vals)/maxval)
plotAS7263NormalizedData2(silicon_test)
# Out:
# 2362.09

# %%
print csvToNumpy(SILICON_CALIBRATION_DATA)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-264-4a50e9f3ef5e> in <module>()
# ----> 1 print csvToNumpy(SILICON_CALIBRATION_DATA)
#
# NameError: name 'csvToNumpy' is not defined

# %%
redlaserlowresspect = [[14.89, 146.26, 2.42, 3.19, 30.2, 6.06],
[14.89, 146.26, 2.42, 3.19, 30.2, 6.06],
[14.89, 146.26, 2.42, 3.19, 30.2, 6.06],
[14.89, 146.26, 2.42, 3.19, 30.2, 6.06],
[14.89, 146.26, 2.42, 3.19, 30.2, 6.06],
[14.89, 146.26, 2.42, 3.19, 30.2, 6.06],
[14.89, 146.26, 2.42, 3.19, 30.2, 6.06],
[14.89, 146.26, 2.42, 3.19, 30.2, 6.06],
[14.89, 146.26, 2.42, 3.19, 30.2, 6.06],
[14.89, 146.26, 2.42, 3.19, 30.2, 6.06],
[14.89, 146.26, 2.42, 3.19, 30.2, 6.06],
[14.89, 146.26, 2.42, 3.19, 30.2, 6.06],
[14.89, 146.26, 2.42, 3.19, 30.2, 6.06],
[14.89, 146.26, 2.42, 3.19, 30.2, 6.06],
[14.89, 146.26, 2.42, 3.19, 30.2, 6.06],
[14.89, 146.26, 2.42, 3.19, 30.2, 6.06],
[14.89, 146.26, 2.42, 3.19, 30.2, 6.06],
[14.89, 146.26, 2.42, 3.19, 30.2, 6.06],
[14.89, 146.26, 2.42, 3.19, 30.2, 6.06],
[14.89, 146.26, 2.42, 3.19, 30.2, 6.06],
[14.89, 146.26, 2.42, 3.19, 30.2, 6.06],
[14.89, 146.26, 2.42, 3.19, 30.2, 6.06],
[14.89, 146.26, 2.42, 3.19, 30.2, 6.06],
[14.89, 146.26, 2.42, 3.19, 30.2, 6.06],
[14.89, 146.26, 2.42, 3.19, 30.2, 6.06],
[14.89, 146.26, 2.42, 3.19, 30.2, 6.06]]

plt.plot(BAND,np.transpose(redlaserlowresspect))

# %%
diffuse_laser_data = [
[52.1, 66624.6, 182.5, 1478.6, 2705.7, 3827.4],
[52.1, 66624.6, 182.5, 1478.6, 2705.7, 3827.4],
[97.6, 66624.6, 194.1, 2013.0, 2705.7, 8813.9],
[97.6, 67355.5, 187.2, 1480.7, 2775.2, 8813.9],
[80.2, 67355.5, 158.3, 1192.4, 2775.2, 6723.0],
[80.2, 67355.5, 158.3, 1192.4, 2775.2, 6723.0],
[80.2, 56860.0, 146.7, 938.9, 1536.6, 6723.0],
[72.2, 56860.0, 135.2, 1173.4, 1536.6, 5792.5],
[72.2, 56860.0, 135.2, 1173.4, 1536.6, 5792.5],
[72.2, 17608.6, 58.9, 522.8, 1195.3, 5792.5]]

# %%
REDLASER = open('../SpectraSuiteData/redlasercallibrationhighres.txt')
values = REDLASER.read().split('\n')
bands = []
intensity = []
plt.figure(figsize=(10,6))
for vals in values: 
    val = vals.split('\t')
    if(val[0] and val[1]): 
        bands.append(val[0])
        intensity.append(float(val[1]))
        
max_intensity = max(intensity)
#print max_intensity
plt.plot(bands,np.array(intensity) / max_intensity, label='Ocean Optics USB4000 (650nm Laser Pointer)')
max_lowres = np.max(redlaserlowresspect[0])
max_diffuse_lowres = np.max(diffuse_laser_data)

for i,row in enumerate(diffuse_laser_data):
    diffuse_laser_data[i] = np.array(row) / max(row)
    
plt.bar(BAND,np.transpose(np.array(redlaserlowresspect[0]/max_lowres)), width = 30, label='AS7263 (650nm Laser Pointer)')
plt.bar(BAND,np.transpose(np.array(diffuse_laser_data)[3]),width = 30, label='AS7263 (Diffuse 650nm Laser Source)')
plt.legend(loc= 'upper right')
plt.xlim((550,900))
#plt.show()
plt.xlabel('wavelength (nm)')
plt.ylabel('Normalized Intensity (counts)')
plt.title('650nm Laser Readings Ocean Optics USB4000 vs. AS7263')
plt.show()
#plt.savefig('../Results/LaserComparison')
